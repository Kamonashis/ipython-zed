# %% [markdown]
# # Analysis
# Some **text** with `code` and $math$.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"a": [1, 2], "b": [3, 4]})
print(f"rows: {len(df)}\n")
df
# Out:
# hello world
#    a  b
# 0  1  2
# ---

# %% [raw]
# just a plain string source
